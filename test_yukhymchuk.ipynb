# %%
a= 2
b = 3
c= a+b 
c= c*2 + 120 
print(c)
# Out:
# 130

# %%
# !pwd
# Out:
# /Users/julia

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.cos(range(30)), color = 'red', marker = '.' )

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("Hello Universe")
# Out:
# Hello Universe
